# %% [markdown]
# Do as Directed:
# Use fundamentals of Numpy and Pandas
# 1. Read the three csv files which contains the score of same students in term1 for each Subject
# 2. Remove the name and ethnicity column (to ensure confidentiality)
# 3. Fill missing score data with zero
# 4. Merge two files
# 5. Change Sex(M/F) Column to 1/2 for further analysis
# 6. Store the data in new file –ScoreFinal.csv
# 7. Convert ethnicity to numerical value
# 8. Fill the missing score for a student to the average of the class

# %%
import numpy as np
import pandas as pd

# %%
# 1.Read the three csv files which contains the score of same students in term1 for each Subject
df1=pd.read_csv('/content/DSScoreTerm1 - DSScoreTerm1.csv')
df2=pd.read_csv('/content/MathScoreTerm1 - MathScoreTerm1.csv')
df3=pd.read_csv('/content/PhysicsScoreTerm1 - PhysicsScoreTerm1.csv')

# %%
df1.head()
# Out:
#              Name  Score  Age         Ethinicity        Subject Sex  ID
# 0  AI-KYUNG CHUNG   82.0   18     White American  Data Structue   M   1
# 1     ALAN HARVEY   79.0   19  European American  Data Structue   M   2
# 2    ALAN REYNAUD   39.0   19  European American  Data Structue   M   3
# 3  ALBERT CENDANA   76.0   18     White American  Data Structue   M   4
# 4  ALBERT HOLT JR   76.0   18     White American  Data Structue   F   5

# %%
df2.head()
# Out:
#              Name  Score  Age         Ethinicity Subject Sex  ID
# 0  AI-KYUNG CHUNG   88.0   18     White American   Maths   M   1
# 1     ALAN HARVEY   85.0   19  European American   Maths   M   2
# 2    ALAN REYNAUD   45.0   19  European American   Maths   M   3
# 3  ALBERT CENDANA   82.0   18     White American   Maths   M   4
# 4  ALBERT HOLT JR   82.0   18     White American   Maths   F   5

# %%
df3.head()
# Out:
#              Name  Score  Age         Ethinicity  Subject Sex  ID
# 0  AI-KYUNG CHUNG   84.0   18     White American  Physics   M   1
# 1     ALAN HARVEY   81.0   19  European American  Physics   M   2
# 2    ALAN REYNAUD   41.0   19  European American  Physics   M   3
# 3  ALBERT CENDANA   78.0   18     White American  Physics   M   4
# 4  ALBERT HOLT JR   78.0   18     White American  Physics   F   5

# %%
# 2.Remove the name and ethnicity column (to ensure confidentiality)
df1=df1.drop(['Name','Ethinicity'],axis=1)

# %%
df2=df2.drop(['Name','Ethinicity'],axis=1)
df3=df3.drop(['Name','Ethinicity'],axis=1)

# %%
df1.head()
# Out:
#      Score  Age        Subject Sex   ID
# 0     82.0   18  Data Structue   M    1
# 1     79.0   19  Data Structue   M    2
# 2     39.0   19  Data Structue   M    3
# 3     76.0   18  Data Structue   M    4
# 4     76.0   18  Data Structue   F    5
# ..     ...  ...            ...  ..  ...
# 594   39.0   19  Data Structue   F  595
# 595   69.0   18  Data Structue   M  596
# 596   47.0   20  Data Structue   M  597
# 597   69.0   20  Data Structue   M  598
# 598    NaN   19  Data Structue   M  599
#
# [599 rows x 5 columns]

# %%
df2.head()
# Out:
#    Score  Age Subject Sex  ID
# 0   88.0   18   Maths   M   1
# 1   85.0   19   Maths   M   2
# 2   45.0   19   Maths   M   3
# 3   82.0   18   Maths   M   4
# 4   82.0   18   Maths   F   5
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1128720221127547221 = autoviz.get_df('df_1128720221127547221')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1128720221127547221, *['Score'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# ...

# %%
df3.head()
# Out:
#    Score  Age  Subject Sex  ID
# 0   84.0   18  Physics   M   1
# 1   81.0   19  Physics   M   2
# 2   41.0   19  Physics   M   3
# 3   78.0   18  Physics   M   4
# 4   78.0   18  Physics   F   5

# %%
# 3.Fill missing score data with zero
print(df1.isna().sum())
print(df2.isna().sum())
print(df3.isna().sum())
# Out:
# Score      8
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64
# Score      3
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64
# Score      6
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64

# %%
df1=df1.fillna(0)
df2=df2.fillna(0)
df3=df3.fillna(0)

# %%
print(df1.isna().sum())
print(df2.isna().sum())
print(df3.isna().sum())
# Out:
# Score      0
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64
# Score      0
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64
# Score      0
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64

# %%
#4. Merge two files
# using merge function by setting how='inner'
out1= pd.merge(df1, df2,
                   on=['ID','Age','Sex'],
                   how='inner')

# %%
out2=pd.merge(df3,out1,on=['ID','Age','Sex'],how='inner')

# %%
out2.head()
# Out:
#    Score  Age  Subject Sex  ID  Score_x      Subject_x  Score_y Subject_y
# 0   84.0   18  Physics   M   1     82.0  Data Structue     88.0     Maths
# 1   81.0   19  Physics   M   2     79.0  Data Structue     85.0     Maths
# 2   41.0   19  Physics   M   3     39.0  Data Structue     45.0     Maths
# 3   78.0   18  Physics   M   4     76.0  Data Structue     82.0     Maths
# 4   78.0   18  Physics   F   5     76.0  Data Structue     82.0     Maths

# %%
# 4 Change Sex(M/F) Column to 1/2 for further analysis
out2=out2.replace('M',1)
out2=out2.replace('F',2)

# %%
out2.head()
# Out:
#    Score  Age  Subject  Sex  ID  Score_x      Subject_x  Score_y Subject_y
# 0   84.0   18  Physics    1   1     82.0  Data Structue     88.0     Maths
# 1   81.0   19  Physics    1   2     79.0  Data Structue     85.0     Maths
# 2   41.0   19  Physics    1   3     39.0  Data Structue     45.0     Maths
# 3   78.0   18  Physics    1   4     76.0  Data Structue     82.0     Maths
# 4   78.0   18  Physics    2   5     76.0  Data Structue     82.0     Maths

# %%
# 6. Store the data in new file –ScoreFinal.csv
out2.to_csv('ScoreFinal.csv')

# %%
# 7.Convert ethnicity to numerical value
from sklearn import preprocessing
encoder=preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df3=pd.read_csv('/content/PhysicsScoreTerm1 - PhysicsScoreTerm1.csv')
df3['Ethinicity']= encoder.fit_transform(df3['Ethinicity'])
df3.head()
# Out:
#              Name  Score  Age  Ethinicity  Subject Sex  ID
# 0  AI-KYUNG CHUNG   84.0   18           3  Physics   M   1
# 1     ALAN HARVEY   81.0   19           1  Physics   M   2
# 2    ALAN REYNAUD   41.0   19           1  Physics   M   3
# 3  ALBERT CENDANA   78.0   18           3  Physics   M   4
# 4  ALBERT HOLT JR   78.0   18           3  Physics   F   5

# %%
#8.Fill the missing score for a student to the average of the class
df3.isna().sum()
# Out:
# Name          0
# Score         6
# Age           0
# Ethinicity    0
# Subject       0
# Sex           0
# ID            0
# dtype: int64

# %%
df3['Score']=df3['Score'].fillna(df3['Score'].mean())

# %%
df3.isna().sum()
# Out:
# Name          0
# Score         0
# Age           0
# Ethinicity    0
# Subject       0
# Sex           0
# ID            0
# dtype: int64

# %% [markdown]
# Visualization

# %%
sale=pd.read_csv('/content/sales_data_sample.csv',sep=",", encoding='Latin-1')

# %%
sale
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
sale.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(sale['PRODUCTLINE'],sale['QUANTITYORDERED'],width=0.5)
plt.xlabel('ProductLine')
plt.ylabel('QUANTITYORDERED')
plt.show()

# %%
sale['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
#2. Plot boxplot for total sales values for each year and present the analysis.
sale.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
plt.boxplot(sale['SALES'])
plt.show()

# %%
# 3.Plot scatter plot for total sales value for each year and present the analysis
plt.scatter(sale['SALES'], sale['YEAR_ID'])
plt.show()
