# %% [markdown]
# Get the Libraries

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import re
from textblob import TextBlob
import string

# %% [markdown]
# Download all the dependencies, 'punkt' is used for pre trained tokenization and stopwords for pre trained stopwords.

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Anindya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anindya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Loading the files from the given text files in the drive, Converted those text file to UTF-8 Encoded files as UTF-8 encoded files have various advantages, <br>
# UTF-8 is backward compatible with ASCII, which means that files containing only ASCII characters are also valid UTF-8 files. <br>
# UTF-8 is a variable-width encoding, allowing it to represent an extensive range of characters.<br>
#
# load_words_from_file function:<br>
# This function takes a file path as an argument then it opens the file in read mode using UTF-8 encoding.<br>
# It reads the contents of the file, splits them into lines (using splitlines()), and stores them in a list called words, Finally, it returns a set containing the unique words from the file.
# <br> <br>
# load_stopwords() Function:<br>
# This function is responsible for loading stopwords from multiple text files and combining them into a single set.<br>
# It initializes an empty set called stop_words.<br>
# It iterates through a list of stopwords files (stopwords_files), and for each file, it updates the stop_words set by adding the words from that file.<br>
# The function then returns the consolidated set of stopwords.

# %%
# loading words from the text files provided in the drive
def load_words_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        words = file.read().splitlines()
    return set(words)

# loading positive and negative words from text files
positive_words = load_words_from_file("positive-words.txt")
negative_words = load_words_from_file("negative-words.txt")

# function to load various stopword files
def load_stopwords():
    stop_words = set()
    stopwords_files = ["StopWords_Auditor.txt", "StopWords_Currencies.txt", "StopWords_DatesandNumbers.txt",
                        "StopWords_Generic.txt", "StopWords_GenericLong.txt", "StopWords_Geographic.txt",
                        "StopWords_Names.txt"]
    for file_name in stopwords_files:
        stop_words.update(load_words_from_file(file_name))
    return stop_words

# %% [markdown]
# stop_words = load_stopwords()<br>
# This line of code is used to load the stopwords into a varioable, will later be used for filtering out common words in the text during text analysis.<br>
# <br>
# count_syllables(word) Function:<br>
# It uses a simple algorithm to count syllables:<br>
# If the word starts with a vowel, it is counted as one syllable.<br>
# Additional syllables are counted based on consecutive vowels.<br>
# Silent 'e' at the end is excluded unless the word ends with two vowels (e.g., "lee").<br>
# The function is made to handle common cases for English words and is used later in the code for syllable counting in text analysis tasks.

# %%
# loading stopwords to a variable for future use
stop_words = load_stopwords()
# function to count syllables in a word
def count_syllables(word):
    vowels = "aeiouy"
    count = 0
    if word[0] in vowels: # if the word starts with a vowel, count it as one syllable
        count += 1
    for index in range(1, len(word)): # counting additional syllables based on consecutive vowels
        if word[index] in vowels and word[index - 1] not in vowels:
            count += 1 
    if word.endswith("e") and word[-2] not in vowels:  # excluding silent 'e' at the end
        count -= 1
    count = max(1, count) # ensuring at least one syllable for short words
    return count

# %% [markdown]
# Tokenization:<br>
# words = word_tokenize(text): This line uses the word_tokenize function from the nltk.tokenize module to split the input text into a list of words. Tokenization is the process of breaking down a text into individual words.<br>
#
# Calculating Total Syllables:<br>
# total_syllables = sum(count_syllables(word) for word in words): This line calculates the total number of syllables in the text by summing the syllable count for each word. The count_syllables function, defined earlier, is used here to count syllables for each word.<br>
#
# Calculating Total Words:<br>
# total_words = len(words): This line calculates the total number of words in the text.<br>
#
# Handling Division by Zero:<br>
# total_words = max(1, total_words): This line ensures that there is at least one word to avoid division by zero. If the text is empty or has no words, it sets total_words to 1.<br>
#
# Calculating Average Syllables per Word:<br>
# avg_syllables_per_word = total_syllables / total_words: This line computes the average number of syllables per word by dividing the total syllables by the total words.<br>
#
# Returning the Result:<br>
# return avg_syllables_per_word: The function returns the calculated average syllables per word.

# %%
# function for calculating the average number of syllables per word in a text
def calculate_avg_syllables_per_word(text):
    words = word_tokenize(text)
    total_syllables = sum(count_syllables(word) for word in words)
    total_words = len(words)
    total_words = max(1, total_words) # avoids division with zero
    avg_syllables_per_word = total_syllables / total_words
    return avg_syllables_per_word

# %% [markdown]
# Identifying Complex Words:<br>
# complex_words = [word for word in words if count_syllables(word) > 2]: This line creates a list of words from the tokenized text, considering only those words with more than 2 syllables. The count_syllables function, defined earlier, is used to count syllables for each word.<br>
#
# Calculating Percentage of Complex Words:<br>
# percentage_complex_words = (len(complex_words) / len(words)) * 100: This line calculates the percentage of complex words by dividing the count of complex words by the total number of words and then multiplying by 100 to express it as a percentage.

# %%
# function for calculating the percentage of complex words
def calculate_complexity(text):
    words = word_tokenize(text)
    complex_words = [word for word in words if count_syllables(word) > 2]  
    percentage_complex_words = (len(complex_words) / len(words)) * 100
    return percentage_complex_words

# %%
# function for calculating Fog Index
def calculate_fog_index(avg_sentence_length, percentage_complex_words):
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
    return fog_index

# %% [markdown]
# Personal Pronouns:<br>
# personal_pronouns: A list containing specific personal pronouns such as 'I', 'we', 'my', 'ours', and 'us'.
# Regex Counting:<br>
#
# The function uses a regular expression (regex) to find and count the occurrences of each personal pronoun in the given text. The re.findall function is employed for this purpose.

# %%
# function for counting personal pronouns
def count_personal_pronouns(text):
    personal_pronouns = ['i', 'we', 'my', 'ours', 'us']
    counts = {pronoun: len(re.findall(r'\b' + pronoun + r'\b', text.lower())) for pronoun in personal_pronouns}
    counts = {pronoun: int(count) for pronoun, count in counts.items()}
    total_count = sum(counts.values())
    return total_count

# %% [markdown]
# Stopwords and Punctuation Removal:<br>
# The function now removes stopwords and punctuation from the words list, creating a words_without_stopwords list.<br>
#
# Updated Score Calculation:<br>
# Positive and negative scores are now calculated based on the words_without_stopwords list.<br>
#
# Subjectivity Score Update:<br>
# The subjectivity score is adjusted to consider the length of words_without_stopwords.<br>
#
# Average Word Per Sentence Update:<br>
# The avg_words_per_sentence calculation now uses the length of words_without_stopwords.

# %%
# function to analyze text and compute variables
def analyze_text(text, positive_words, negative_words, stop_words):
    blob = TextBlob(text)
    sentiment = blob.sentiment
    words = word_tokenize(text.lower())  
    # removing stopwords and punctuation
    words_without_stopwords = [word for word in words if word not in stop_words and word not in string.punctuation]
    positive_score = sum(1 for word in words if word in positive_words)
    negative_score = sum(1 for word in words if word in negative_words)
    polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
    subjectivity_score = (positive_score + negative_score) / (len(words) + 0.000001)
    sentences = sent_tokenize(text)
    words = word_tokenize(text) # removing punctuation
    # removing stopwords
    words_without_stopwords = [word for word in words if word.lower() not in stop_words and word not in string.punctuation]
    avg_sentence_length = len(words_without_stopwords) / len(sentences)
    avg_words_per_sentence = len(words) / len(sentences)  
    percentage_complex_words = calculate_complexity(text)
    fog_index = calculate_fog_index(avg_sentence_length, percentage_complex_words)
    
    complex_word_count = len([word for word in words_without_stopwords if len(word) > 6])  

    avg_word_length = sum(len(word) for word in words_without_stopwords) / len(words_without_stopwords)

    avg_syllables_per_word = calculate_avg_syllables_per_word(text)

    personal_pronoun_count = count_personal_pronouns(text)

    return positive_score, negative_score, polarity_score, subjectivity_score, avg_sentence_length, percentage_complex_words, fog_index, avg_words_per_sentence, complex_word_count, len(words_without_stopwords), avg_syllables_per_word, avg_word_length, personal_pronoun_count

# %% [markdown]
# This part of the code processes all text files from "blackassign0001.txt" to "blackassign0100.txt" and analyzes each file using the analyze_text function. <br>

# %%
# processing all text files from blackassign0001.txt to blackassign0100.txt
for i in range(1, 101):
    file_name = f"blackassign{str(i).zfill(4)}.txt"
    file_path = f"{file_name}"  # Replace with the actual path to your files

    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            article_text = file.read()
        results = analyze_text(article_text, positive_words, negative_words, stop_words)
        columns = ['Positive_Score', 'Negative_Score', 'Polarity_Score', 'Subjectivity_Score', 'Avg_Sentence_Length',
                   'Percentage_of_Complex_Words', 'Fog_Index', 'Avg_Number_of_Words_Per_Sentence', 'Complex_Word_Count',
                   'Word_Count', 'Avg_Syllables_Per_Word', 'Avg_Word_Length', 'Personal_Pronoun_Count']

        print(f"\nResults for {file_name}:")
        for col, result in zip(columns, results):
            print(f"{col}: {result}")

    except FileNotFoundError:
        print(f"\nFile {file_name} not found. Skipping...")
        continue
# Out:
# Results for blackassign0001.txt:
# Positive_Score: 44
# Negative_Score: 5
# Polarity_Score: 0.7959183511037071
# Subjectivity_Score: 0.03717754170168623
# Avg_Sentence_Length: 7.538461538461538
# Percentage_of_Complex_Words: 11.10271903323263
# Fog_Index: 7.456472228677668
# Avg_Number_of_Words_Per_Sentence: 16.974358974358974
# Complex_Word_Count: 224
# Word_Count: 588
# Avg_Syllables_Per_Word: 1.450906344410876
# Avg_Word_Length: 5.95578231292517
# Personal_Pronoun_Count: 12
#
# Results for blackassign0002.txt:
# Positive_Score: 66
# Negative_Score: 31
# Polarity_Score: 0.3608247385481986
# Subjectivity_Score: 0.05699177434959355
# Avg_Sentence_Length: 10.632911392405063
# Percentage_of_Complex_Words: 20.211515863689776
# Fog_Index: 12.337770902437937
# Avg_Number_of_Words_Per_Sentence: 21.544303797468356
# Complex_Word_Count: 446
# Word_Count: 840
# Avg_Syllables_Per_Word: 1.726792009400705
# Avg_Word_Length: 7.095238095238095
# Personal_Pronoun_Count: 6
#
# Results for blackassign0003.txt:
# Positive_Score: 40
# Negative_Score: 23
# Polarity_Score: 0.26984126555807514
# Subjectivity_Score: 0.052852348948949364
# Avg_Sentence_Length: 11.125
# Percentage_of_Complex_Words: 27.097315436241608
# Fog_Index: 15.288926174496645
# Avg_Number_of_Words_Per_Sentence: 21.285714285714285
# Complex_Word_Count: 426
# Word_Count: 623
# Avg_Syllables_Per_Word: 1.9437919463087248
# Avg_Word_Length: 8.035313001605136
# Personal_Pronoun_Count: 13
#
# Results for blackassign0004.txt:
# Positive_Score: 40
# Negative_Score: 72
# Polarity_Score: -0.28571428316326536
# Subjectivity_Score: 0.09589041087680615
# Avg_Sentence_Length: 11.901960784313726
# Percentage_of_Complex_Words: 25.831202046035806
# Fog_Index: 15.093265132139813
# Avg_Number_of_Words_Per_Sentence: 23.0
# Complex_Word_Count: 412
# Word_Count: 607
# Avg_Syllables_Per_Word: 1.855924978687127
# Avg_Word_Length: 7.792421746293246
# Personal_Pronoun_Count: 5
#
# Results for blackassign0005.txt:
# Positive_Score: 23
# Negative_Score: 8
# Polarity_Score: 0.4838709521331951
# Subjectivity_Score: 0.04046997383750656
# Avg_Sentence_Length: 9.820512820512821
# Percentage_of_Complex_Words: 19.19060052219321
# Fog_Index: 11.604445337082414
# Avg_Number_of_Words_Per_Sentence: 19.641025641025642
# Complex_Word_Count: 229
# Word_Count: 383
# Avg_Syllables_Per_Word: 1.6840731070496084
# Avg_Word_Length: 7.310704960835509
# Personal_Pronoun_Count: 6
#
# Results for blackassign0006.txt:
# Positive_Score: 89
# Negative_Score: 27
# Polarity_Score: 0.5344827540130798
# Subjectivity_Score: 0.057511155152448604
# Avg_Sentence_Length: 12.465909090909092
# Percentage_of_Complex_Words: 25.333333333333336
# Fog_Index: 15.119696969696973
# Avg_Number_of_Words_Per_Sentence: 23.011363636363637
# Complex_Word_Count: 738
# Word_Count: 1097
# Avg_Syllables_Per_Word: 1.8493827160493828
# Avg_Word_Length: 7.605287146763901
# Personal_Pronoun_Count: 6
#
# Results for blackassign0007.txt:
# Positive_Score: 31
# Negative_Score: 66
# Polarity_Score: -0.3608247385481986
# Subjectivity_Score: 0.06708160437961161
# Avg_Sentence_Length: 10.608695652173912
# Percentage_of_Complex_Words: 19.502074688796682
# Fog_Index: 12.044308136388238
# Avg_Number_of_Words_Per_Sentence: 20.956521739130434
# Complex_Word_Count: 391
# Word_Count: 732
# Avg_Syllables_Per_Word: 1.6887966804979253
# Avg_Word_Length: 6.709016393442623
# Personal_Pronoun_Count: 1
#
# Results for blackassign0008.txt:
# Positive_Score: 31
# Negative_Score: 9
# Polarity_Score: 0.5499999862500004
# Subjectivity_Score: 0.04932182484670552
# Avg_Sentence_Length: 11.789473684210526
# Percentage_of_Complex_Words: 29.361179361179364
# Fog_Index: 16.460261218155956
# Avg_Number_of_Words_Per_Sentence: 21.42105263157895
# Complex_Word_Count: 310
# Word_Count: 448
# Avg_Syllables_Per_Word: 1.9864864864864864
# Avg_Word_Length: 8.109375
# Personal_Pronoun_Count: 3
#
# Results for blackassign0009.txt:
# Positive_Score: 43
# Negative_Score: 49
# Polarity_Score: -0.06521739059546315
# Subjectivity_Score: 0.08984374991226195
# Avg_Sentence_Length: 11.36734693877551
# Percentage_of_Complex_Words: 29.95121951219512
# Fog_Index: 16.52742658038825
# Avg_Number_of_Words_Per_Sentence: 20.918367346938776
# Complex_Word_Count: 385
# Word_Count: 557
# Avg_Syllables_Per_Word: 1.9697560975609756
# Avg_Word_Length: 8.102333931777379
# Personal_Pronoun_Count: 3
#
# Results for blackassign0010.txt:
# Positive_Score: 145
# Negative_Score: 181
# Polarity_Score: -0.1104294475140201
# Subjectivity_Score: 0.07832772703548108
# Avg_Sentence_Length: 7.907949790794979
# Percentage_of_Complex_Words: 21.098058019659554
# Fog_Index: 11.602403124181814
# Avg_Number_of_Words_Per_Sentence: 17.451882845188283
# Complex_Word_Count: 1124
# Word_Count: 1890
# Avg_Syllables_Per_Word: 1.7115799568448813
# Avg_Word_Length: 7.303703703703704
# Personal_Pronoun_Count: 13
#
# Results for blackassign0011.txt:
# Positive_Score: 65
# Negative_Score: 19
# Polarity_Score: 0.5476190410997733
# Subjectivity_Score: 0.05408886023561567
# Avg_Sentence_Length: 12.044776119402986
# Percentage_of_Complex_Words: 22.91933418693982
# Fog_Index: 13.985644122537122
# Avg_Number_of_Words_Per_Sentence: 23.313432835820894
# Complex_Word_Count: 507
# Word_Count: 807
# Avg_Syllables_Per_Word: 1.8284250960307298
# Avg_Word_Length: 7.655514250309789
# Personal_Pronoun_Count: 3
#
# Results for blackassign0012.txt:
# Positive_Score: 88
# Negative_Score: 24
# Polarity_Score: 0.5714285663265307
# Subjectivity_Score: 0.060573282822837596
# Avg_Sentence_Length: 11.139240506329115
# Percentage_of_Complex_Words: 19.740400216333153
# Fog_Index: 12.351856289064907
# Avg_Number_of_Words_Per_Sentence: 23.40506329113924
# Complex_Word_Count: 553
# Word_Count: 880
# Avg_Syllables_Per_Word: 1.7652785289345592
# Avg_Word_Length: 7.596590909090909
# Personal_Pronoun_Count: 2
#
# Results for blackassign0013.txt:
# Positive_Score: 41
# Negative_Score: 13
# Polarity_Score: 0.5185185089163239
# Subjectivity_Score: 0.08157099685563293
# Avg_Sentence_Length: 12.083333333333334
# Percentage_of_Complex_Words: 22.356495468277945
# Fog_Index: 13.775931520644512
# Avg_Number_of_Words_Per_Sentence: 27.583333333333332
# Complex_Word_Count: 204
# Word_Count: 290
# Avg_Syllables_Per_Word: 1.756797583081571
# Avg_Word_Length: 7.937931034482759
# Personal_Pronoun_Count: 3
#
# Results for blackassign0014.txt:
# Positive_Score: 25
# Negative_Score: 27
# Polarity_Score: -0.03846153772189351
# Subjectivity_Score: 0.0429397192048392
# Avg_Sentence_Length: 8.426470588235293
# Percentage_of_Complex_Words: 18.38417147568013
# Fog_Index: 10.72425682556617
# Avg_Number_of_Words_Per_Sentence: 17.83823529411765
# Complex_Word_Count: 336
# Word_Count: 573
# Avg_Syllables_Per_Word: 1.6578730420445178
# Avg_Word_Length: 7.020942408376963
# Personal_Pronoun_Count: 3
#
# Results for blackassign0015.txt:
# Positive_Score: 42
# Negative_Score: 27
# Polarity_Score: 0.21739130119722752
# Subjectivity_Score: 0.05176294069635188
# Avg_Sentence_Length: 11.431034482758621
# Percentage_of_Complex_Words: 21.005251312828207
# Fog_Index: 12.974514318234732
# Avg_Number_of_Words_Per_Sentence: 22.982758620689655
# Complex_Word_Count: 395
# Word_Count: 663
# Avg_Syllables_Per_Word: 1.7149287321830458
# Avg_Word_Length: 7.174962292609352
# Personal_Pronoun_Count: 7
#
# Results for blackassign0016.txt:
# Positive_Score: 42
# Negative_Score: 27
# Polarity_Score: 0.21739130119722752
# Subjectivity_Score: 0.05176294069635188
# Avg_Sentence_Length: 11.431034482758621
# Percentage_of_Complex_Words: 21.005251312828207
# Fog_Index: 12.974514318234732
# Avg_Number_of_Words_Per_Sentence: 22.982758620689655
# Complex_Word_Count: 395
# Word_Count: 663
# Avg_Syllables_Per_Word: 1.7149287321830458
# Avg_Word_Length: 7.174962292609352
# Personal_Pronoun_Count: 7
#
# Results for blackassign0017.txt:
# Positive_Score: 56
# Negative_Score: 12
# Polarity_Score: 0.647058814013841
# Subjectivity_Score: 0.052307692267455616
# Avg_Sentence_Length: 9.953125
# Percentage_of_Complex_Words: 21.105141980046046
# Fog_Index: 12.423306792018419
# Avg_Number_of_Words_Per_Sentence: 20.359375
# Complex_Word_Count: 399
# Word_Count: 637
# Avg_Syllables_Per_Word: 1.7260168841135841
# Avg_Word_Length: 7.1051805337519625
# Personal_Pronoun_Count: 5
#
# Results for blackassign0018.txt:
# Positive_Score: 43
# Negative_Score: 10
# Polarity_Score: 0.6226414976860095
# Subjectivity_Score: 0.044801352455789215
# Avg_Sentence_Length: 13.25
# Percentage_of_Complex_Words: 20.9636517328825
# Fog_Index: 13.685460693152999
# Avg_Number_of_Words_Per_Sentence: 26.886363636363637
# Complex_Word_Count: 367
# Word_Count: 583
# Avg_Syllables_Per_Word: 1.7210481825866442
# Avg_Word_Length: 7.276157804459691
# Personal_Pronoun_Count: 1
#
# Results for blackassign0019.txt:
# Positive_Score: 70
# Negative_Score: 6
# Polarity_Score: 0.8421052520775625
# Subjectivity_Score: 0.04040404038256032
# Avg_Sentence_Length: 9.43010752688172
# Percentage_of_Complex_Words: 20.46783625730994
# Fog_Index: 11.959177513676664
# Avg_Number_of_Words_Per_Sentence: 20.225806451612904
# Complex_Word_Count: 521
# Word_Count: 877
# Avg_Syllables_Per_Word: 1.6555023923444976
# Avg_Word_Length: 6.905359179019384
# Personal_Pronoun_Count: 5
#
# Results for blackassign0020.txt:
# Positive_Score: 9
# Negative_Score: 0
# Polarity_Score: 0.9999998888889013
# Subjectivity_Score: 0.014851485124007451
# Avg_Sentence_Length: 8.592592592592593
# Percentage_of_Complex_Words: 12.871287128712872
# Fog_Index: 8.585551888522188
# Avg_Number_of_Words_Per_Sentence: 22.444444444444443
# Complex_Word_Count: 122
# Word_Count: 232
# Avg_Syllables_Per_Word: 1.561056105610561
# Avg_Word_Length: 6.737068965517241
# Personal_Pronoun_Count: 1
#
# Results for blackassign0021.txt:
# Positive_Score: 28
# Negative_Score: 47
# Polarity_Score: -0.25333332995555563
# Subjectivity_Score: 0.06454388978954914
# Avg_Sentence_Length: 11.346938775510203
# Percentage_of_Complex_Words: 23.23580034423408
# Fog_Index: 13.833095647897714
# Avg_Number_of_Words_Per_Sentence: 23.714285714285715
# Complex_Word_Count: 353
# Word_Count: 556
# Avg_Syllables_Per_Word: 1.7555938037865748
# Avg_Word_Length: 7.278776978417266
# Personal_Pronoun_Count: 6
#
# Results for blackassign0022.txt:
# Positive_Score: 15
# Negative_Score: 10
# Polarity_Score: 0.19999999200000032
# Subjectivity_Score: 0.054229934806442656
# Avg_Sentence_Length: 6.962962962962963
# Percentage_of_Complex_Words: 16.268980477223426
# Fog_Index: 9.292777376074556
# Avg_Number_of_Words_Per_Sentence: 17.074074074074073
# Complex_Word_Count: 99
# Word_Count: 188
# Avg_Syllables_Per_Word: 1.6182212581344901
# Avg_Word_Length: 6.946808510638298
# Personal_Pronoun_Count: 6
#
# Results for blackassign0023.txt:
# Positive_Score: 44
# Negative_Score: 15
# Polarity_Score: 0.4915254153978743
# Subjectivity_Score: 0.0385369039591529
# Avg_Sentence_Length: 11.253968253968255
# Percentage_of_Complex_Words: 14.817232375979112
# Fog_Index: 10.428480251978947
# Avg_Number_of_Words_Per_Sentence: 24.317460317460316
# Complex_Word_Count: 317
# Word_Count: 709
# Avg_Syllables_Per_Word: 1.593342036553525
# Avg_Word_Length: 6.655853314527503
# Personal_Pronoun_Count: 7
#
# Results for blackassign0024.txt:
# Positive_Score: 25
# Negative_Score: 3
# Polarity_Score: 0.7857142576530622
# Subjectivity_Score: 0.044164037785230224
# Avg_Sentence_Length: 15.5
# Percentage_of_Complex_Words: 19.055118110236222
# Fog_Index: 13.82204724409449
# Avg_Number_of_Words_Per_Sentence: 31.75
# Complex_Word_Count: 164
# Word_Count: 310
# Avg_Syllables_Per_Word: 1.6535433070866141
# Avg_Word_Length: 6.796774193548387
# Personal_Pronoun_Count: 1
#
# Results for blackassign0025.txt:
# Positive_Score: 26
# Negative_Score: 11
# Polarity_Score: 0.4054053944485029
# Subjectivity_Score: 0.030679933639568873
# Avg_Sentence_Length: 14.307692307692308
# Percentage_of_Complex_Words: 11.497105045492143
# Fog_Index: 10.32191894127378
# Avg_Number_of_Words_Per_Sentence: 31.0
# Complex_Word_Count: 224
# Word_Count: 558
# Avg_Syllables_Per_Word: 1.4607113316790736
# Avg_Word_Length: 5.795698924731183
# Personal_Pronoun_Count: 6
#
# Results for blackassign0026.txt:
# Positive_Score: 29
# Negative_Score: 15
# Polarity_Score: 0.3181818109504134
# Subjectivity_Score: 0.04296874995803832
# Avg_Sentence_Length: 11.222222222222221
# Percentage_of_Complex_Words: 18.634146341463413
# Fog_Index: 11.942547425474254
# Avg_Number_of_Words_Per_Sentence: 22.77777777777778
# Complex_Word_Count: 263
# Word_Count: 505
# Avg_Syllables_Per_Word: 1.6282926829268292
# Avg_Word_Length: 6.667326732673267
# Personal_Pronoun_Count: 2
#
# Results for blackassign0027.txt:
# Positive_Score: 39
# Negative_Score: 26
# Polarity_Score: 0.199999996923077
# Subjectivity_Score: 0.04492052519355872
# Avg_Sentence_Length: 11.50943396226415
# Percentage_of_Complex_Words: 13.007570543702684
# Fog_Index: 9.806801802386735
# Avg_Number_of_Words_Per_Sentence: 27.41509433962264
# Complex_Word_Count: 251
# Word_Count: 610
# Avg_Syllables_Per_Word: 1.4707501720578113
# Avg_Word_Length: 5.981967213114754
# Personal_Pronoun_Count: 27
#
# Results for blackassign0028.txt:
# Positive_Score: 41
# Negative_Score: 27
# Polarity_Score: 0.20588234991349486
# Subjectivity_Score: 0.05358550035178447
# Avg_Sentence_Length: 13.727272727272727
# Percentage_of_Complex_Words: 17.674783974862528
# Fog_Index: 12.560822680854102
# Avg_Number_of_Words_Per_Sentence: 28.931818181818183
# Complex_Word_Count: 335
# Word_Count: 604
# Avg_Syllables_Per_Word: 1.6182246661429693
# Avg_Word_Length: 6.943708609271523
# Personal_Pronoun_Count: 10
#
# Results for blackassign0029.txt:
# Positive_Score: 80
# Negative_Score: 34
# Polarity_Score: 0.403508768390274
# Subjectivity_Score: 0.05728643213201687
# Avg_Sentence_Length: 14.013333333333334
# Percentage_of_Complex_Words: 22.462311557788944
# Fog_Index: 14.590257956448912
# Avg_Number_of_Words_Per_Sentence: 26.533333333333335
# Complex_Word_Count: 651
# Word_Count: 1051
# Avg_Syllables_Per_Word: 1.7834170854271356
# Avg_Word_Length: 7.233111322549952
# Personal_Pronoun_Count: 1
#
# Results for blackassign0030.txt:
# Positive_Score: 71
# Negative_Score: 38
# Polarity_Score: 0.3027522908004377
# Subjectivity_Score: 0.06646341459361986
# Avg_Sentence_Length: 8.2875
# Percentage_of_Complex_Words: 14.74710542352224
# Fog_Index: 9.213842169408897
# Avg_Number_of_Words_Per_Sentence: 20.5125
# Complex_Word_Count: 308
# Word_Count: 663
# Avg_Syllables_Per_Word: 1.5143205362583791
# Avg_Word_Length: 6.386123680241328
# Personal_Pronoun_Count: 7
#
# Results for blackassign0031.txt:
# Positive_Score: 72
# Negative_Score: 38
# Polarity_Score: 0.3090909062809918
# Subjectivity_Score: 0.058078141468807735
# Avg_Sentence_Length: 10.588235294117647
# Percentage_of_Complex_Words: 20.96092925026399
# Fog_Index: 12.619665817752656
# Avg_Number_of_Words_Per_Sentence: 22.28235294117647
# Complex_Word_Count: 554
# Word_Count: 900
# Avg_Syllables_Per_Word: 1.7412882787750792
# Avg_Word_Length: 7.17
# Personal_Pronoun_Count: 3
#
# Results for blackassign0032.txt:
# Positive_Score: 83
# Negative_Score: 26
# Polarity_Score: 0.5229357750189378
# Subjectivity_Score: 0.060387811600893175
# Avg_Sentence_Length: 7.7894736842105265
# Percentage_of_Complex_Words: 13.739612188365651
# Fog_Index: 8.611634349030473
# Avg_Number_of_Words_Per_Sentence: 19.0
# Complex_Word_Count: 344
# Word_Count: 740
# Avg_Syllables_Per_Word: 1.5168975069252078
# Avg_Word_Length: 6.351351351351352
# Personal_Pronoun_Count: 18
#
# Results for blackassign0033.txt:
# Positive_Score: 66
# Negative_Score: 25
# Polarity_Score: 0.45054944559835775
# Subjectivity_Score: 0.04724818273766968
# Avg_Sentence_Length: 11.428571428571429
# Percentage_of_Complex_Words: 16.1993769470405
# Fog_Index: 11.051179350244773
# Avg_Number_of_Words_Per_Sentence: 25.01298701298701
# Complex_Word_Count: 441
# Word_Count: 880
# Avg_Syllables_Per_Word: 1.57736240913811
# Avg_Word_Length: 6.571590909090909
# Personal_Pronoun_Count: 18
#
# Results for blackassign0034.txt:
# Positive_Score: 57
# Negative_Score: 23
# Polarity_Score: 0.4249999946875001
# Subjectivity_Score: 0.05505849961799139
# Avg_Sentence_Length: 10.333333333333334
# Percentage_of_Complex_Words: 15.120274914089347
# Fog_Index: 10.181443298969072
# Avg_Number_of_Words_Per_Sentence: 24.25
# Complex_Word_Count: 312
# Word_Count: 620
# Avg_Syllables_Per_Word: 1.5532646048109966
# Avg_Word_Length: 6.540322580645161
# Personal_Pronoun_Count: 21
#
# Results for blackassign0035.txt:
# Positive_Score: 29
# Negative_Score: 12
# Polarity_Score: 0.4146341362284357
# Subjectivity_Score: 0.04875148626783414
# Avg_Sentence_Length: 8.155555555555555
# Percentage_of_Complex_Words: 18.90606420927467
# Fog_Index: 10.82464790593209
# Avg_Number_of_Words_Per_Sentence: 18.68888888888889
# Complex_Word_Count: 186
# Word_Count: 367
# Avg_Syllables_Per_Word: 1.6052318668252081
# Avg_Word_Length: 6.716621253405995
# Personal_Pronoun_Count: 7
#
# File blackassign0036.txt not found. Skipping...
#
# Results for blackassign0037.txt:
# Positive_Score: 44
# Negative_Score: 13
# Polarity_Score: 0.5438596395814098
# Subjectivity_Score: 0.0708074533281895
# Avg_Sentence_Length: 10.055555555555555
# Percentage_of_Complex_Words: 12.655086848635236
# Fog_Index: 9.084256961676317
# Avg_Number_of_Words_Per_Sentence: 22.38888888888889
# Complex_Word_Count: 180
# Word_Count: 362
# Avg_Syllables_Per_Word: 1.4739454094292803
# Avg_Word_Length: 6.218232044198895
# Personal_Pronoun_Count: 2
#
# Results for blackassign0038.txt:
# Positive_Score: 80
# Negative_Score: 41
# Polarity_Score: 0.3223140469230244
# Subjectivity_Score: 0.050712489500958725
# Avg_Sentence_Length: 13.209876543209877
# Percentage_of_Complex_Words: 16.883116883116884
# Fog_Index: 12.037197370530706
# Avg_Number_of_Words_Per_Sentence: 29.469135802469136
# Complex_Word_Count: 524
# Word_Count: 1070
# Avg_Syllables_Per_Word: 1.6007540846250523
# Avg_Word_Length: 6.42803738317757
# Personal_Pronoun_Count: 11
#
# Results for blackassign0039.txt:
# Positive_Score: 60
# Negative_Score: 65
# Polarity_Score: -0.03999999968
# Subjectivity_Score: 0.05411255408912877
# Avg_Sentence_Length: 11.11340206185567
# Percentage_of_Complex_Words: 14.761904761904763
# Fog_Index: 10.350122729504173
# Avg_Number_of_Words_Per_Sentence: 23.814432989690722
# Complex_Word_Count: 537
# Word_Count: 1078
# Avg_Syllables_Per_Word: 1.5675324675324676
# Avg_Word_Length: 6.274582560296846
# Personal_Pronoun_Count: 1
#
# Results for blackassign0040.txt:
# Positive_Score: 47
# Negative_Score: 20
# Polarity_Score: 0.40298506861216316
# Subjectivity_Score: 0.05234374995910644
# Avg_Sentence_Length: 10.60344827586207
# Percentage_of_Complex_Words: 20.9375
# Fog_Index: 12.61637931034483
# Avg_Number_of_Words_Per_Sentence: 22.06896551724138
# Complex_Word_Count: 386
# Word_Count: 615
# Avg_Syllables_Per_Word: 1.71796875
# Avg_Word_Length: 7.20650406504065
# Personal_Pronoun_Count: 10
#
# Results for blackassign0041.txt:
# Positive_Score: 42
# Negative_Score: 29
# Polarity_Score: 0.18309858897044243
# Subjectivity_Score: 0.05049786625142399
# Avg_Sentence_Length: 8.234567901234568
# Percentage_of_Complex_Words: 15.815602836879433
# Fog_Index: 9.620068295245602
# Avg_Number_of_Words_Per_Sentence: 17.40740740740741
# Complex_Word_Count: 307
# Word_Count: 667
# Avg_Syllables_Per_Word: 1.5659574468085107
# Avg_Word_Length: 6.329835082458771
# Personal_Pronoun_Count: 6
#
# Results for blackassign0042.txt:
# Positive_Score: 72
# Negative_Score: 24
# Polarity_Score: 0.49999999479166674
# Subjectivity_Score: 0.05306799333716528
# Avg_Sentence_Length: 10.924242424242424
# Percentage_of_Complex_Words: 15.035931453841902
# Fog_Index: 10.38406955123373
# Avg_Number_of_Words_Per_Sentence: 27.40909090909091
# Complex_Word_Count: 362
# Word_Count: 721
# Avg_Syllables_Per_Word: 1.5550027639579878
# Avg_Word_Length: 6.747572815533981
# Personal_Pronoun_Count: 32
#
# Results for blackassign0043.txt:
# Positive_Score: 81
# Negative_Score: 23
# Polarity_Score: 0.5576923023298818
# Subjectivity_Score: 0.057617728499934774
# Avg_Sentence_Length: 10.325
# Percentage_of_Complex_Words: 17.035398230088493
# Fog_Index: 10.944159292035398
# Avg_Number_of_Words_Per_Sentence: 22.6
# Complex_Word_Count: 424
# Word_Count: 826
# Avg_Syllables_Per_Word: 1.6111725663716814
# Avg_Word_Length: 6.598062953995157
# Personal_Pronoun_Count: 11
#
# Results for blackassign0044.txt:
# Positive_Score: 28
# Negative_Score: 0
# Polarity_Score: 0.9999999642857155
# Subjectivity_Score: 0.04920913875358675
# Avg_Sentence_Length: 13.136363636363637
# Percentage_of_Complex_Words: 20.035149384885763
# Fog_Index: 13.268605208499759
# Avg_Number_of_Words_Per_Sentence: 25.863636363636363
# Complex_Word_Count: 167
# Word_Count: 289
# Avg_Syllables_Per_Word: 1.7275922671353252
# Avg_Word_Length: 7.079584775086505
# Personal_Pronoun_Count: 0
#
# Results for blackassign0045.txt:
# Positive_Score: 104
# Negative_Score: 39
# Polarity_Score: 0.454545451366815
# Subjectivity_Score: 0.07558139530888933
# Avg_Sentence_Length: 89.55555555555556
# Percentage_of_Complex_Words: 14.323467230443976
# Fog_Index: 41.55160911439982
# Avg_Number_of_Words_Per_Sentence: 210.22222222222223
# Complex_Word_Count: 380
# Word_Count: 806
# Avg_Syllables_Per_Word: 1.5375264270613107
# Avg_Word_Length: 6.435483870967742
# Personal_Pronoun_Count: 16
#
# Results for blackassign0046.txt:
# Positive_Score: 34
# Negative_Score: 0
# Polarity_Score: 0.9999999705882362
# Subjectivity_Score: 0.031984948229553195
# Avg_Sentence_Length: 8.696428571428571
# Percentage_of_Complex_Words: 17.96801505174036
# Fog_Index: 10.665777449267573
# Avg_Number_of_Words_Per_Sentence: 18.982142857142858
# Complex_Word_Count: 247
# Word_Count: 487
# Avg_Syllables_Per_Word: 1.5888993414863593
# Avg_Word_Length: 6.519507186858316
# Personal_Pronoun_Count: 0
#
# Results for blackassign0047.txt:
# Positive_Score: 15
# Negative_Score: 6
# Polarity_Score: 0.4285714081632663
# Subjectivity_Score: 0.02716688224169873
# Avg_Sentence_Length: 9.64102564102564
# Percentage_of_Complex_Words: 22.60981912144703
# Fog_Index: 12.900337904989067
# Avg_Number_of_Words_Per_Sentence: 19.846153846153847
# Complex_Word_Count: 222
# Word_Count: 376
# Avg_Syllables_Per_Word: 1.7403100775193798
# Avg_Word_Length: 7.098404255319149
# Personal_Pronoun_Count: 1
#
# Results for blackassign0048.txt:
# Positive_Score: 5
# Negative_Score: 4
# Polarity_Score: 0.11111109876543349
# Subjectivity_Score: 0.026706231374758957
# Avg_Sentence_Length: 11.416666666666666
# Percentage_of_Complex_Words: 19.287833827893174
# Fog_Index: 12.281800197823936
# Avg_Number_of_Words_Per_Sentence: 28.083333333333332
# Complex_Word_Count: 80
# Word_Count: 137
# Avg_Syllables_Per_Word: 1.688427299703264
# Avg_Word_Length: 6.890510948905109
# Personal_Pronoun_Count: 2
#
# File blackassign0049.txt not found. Skipping...
#
# Results for blackassign0050.txt:
# Positive_Score: 35
# Negative_Score: 69
# Polarity_Score: -0.32692307377958585
# Subjectivity_Score: 0.06797385616472297
# Avg_Sentence_Length: 12.963636363636363
# Percentage_of_Complex_Words: 16.60130718954248
# Fog_Index: 11.825977421271539
# Avg_Number_of_Words_Per_Sentence: 27.818181818181817
# Complex_Word_Count: 377
# Word_Count: 713
# Avg_Syllables_Per_Word: 1.6183006535947713
# Avg_Word_Length: 6.789621318373071
# Personal_Pronoun_Count: 2
#
# Results for blackassign0051.txt:
# Positive_Score: 21
# Negative_Score: 15
# Polarity_Score: 0.16666666203703717
# Subjectivity_Score: 0.044554455390402904
# Avg_Sentence_Length: 12.586206896551724
# Percentage_of_Complex_Words: 17.07920792079208
# Fog_Index: 11.866165926937521
# Avg_Number_of_Words_Per_Sentence: 27.862068965517242
# Complex_Word_Count: 194
# Word_Count: 365
# Avg_Syllables_Per_Word: 1.5977722772277227
# Avg_Word_Length: 6.6219178082191785
# Personal_Pronoun_Count: 5
#
# Results for blackassign0052.txt:
# Positive_Score: 72
# Negative_Score: 38
# Polarity_Score: 0.3090909062809918
# Subjectivity_Score: 0.05076142129637221
# Avg_Sentence_Length: 7.990909090909091
# Percentage_of_Complex_Words: 15.274573142593448
# Fog_Index: 9.306192893401017
# Avg_Number_of_Words_Per_Sentence: 19.7
# Complex_Word_Count: 445
# Word_Count: 879
# Avg_Syllables_Per_Word: 1.5477618827872635
# Avg_Word_Length: 6.616609783845279
# Personal_Pronoun_Count: 10
#
# Results for blackassign0053.txt:
# Positive_Score: 53
# Negative_Score: 3
# Polarity_Score: 0.8928571269132657
# Subjectivity_Score: 0.0739762218309429
# Avg_Sentence_Length: 7.8604651162790695
# Percentage_of_Complex_Words: 17.322834645669293
# Fog_Index: 10.073319904779346
# Avg_Number_of_Words_Per_Sentence: 17.72093023255814
# Complex_Word_Count: 177
# Word_Count: 338
# Avg_Syllables_Per_Word: 1.636482939632546
# Avg_Word_Length: 6.849112426035503
# Personal_Pronoun_Count: 4
#
# Results for blackassign0054.txt:
# Positive_Score: 9
# Negative_Score: 1
# Polarity_Score: 0.7999999200000081
# Subjectivity_Score: 0.023923444918843434
# Avg_Sentence_Length: 12.875
# Percentage_of_Complex_Words: 13.875598086124402
# Fog_Index: 10.70023923444976
# Avg_Number_of_Words_Per_Sentence: 26.125
# Complex_Word_Count: 76
# Word_Count: 206
# Avg_Syllables_Per_Word: 1.5167464114832536
# Avg_Word_Length: 6.281553398058253
# Personal_Pronoun_Count: 0
#
# Results for blackassign0055.txt:
# Positive_Score: 34
# Negative_Score: 9
# Polarity_Score: 0.5813953353163875
# Subjectivity_Score: 0.0348460291451815
# Avg_Sentence_Length: 12.340425531914894
# Percentage_of_Complex_Words: 13.187702265372167
# Fog_Index: 10.211251118914825
# Avg_Number_of_Words_Per_Sentence: 26.29787234042553
# Complex_Word_Count: 223
# Word_Count: 580
# Avg_Syllables_Per_Word: 1.5072815533980584
# Avg_Word_Length: 6.022413793103448
# Personal_Pronoun_Count: 4
#
# Results for blackassign0056.txt:
# Positive_Score: 21
# Negative_Score: 7
# Polarity_Score: 0.49999998214285774
# Subjectivity_Score: 0.045161290249739854
# Avg_Sentence_Length: 14.454545454545455
# Percentage_of_Complex_Words: 19.35483870967742
# Fog_Index: 13.523753665689151
# Avg_Number_of_Words_Per_Sentence: 28.181818181818183
# Complex_Word_Count: 171
# Word_Count: 318
# Avg_Syllables_Per_Word: 1.6870967741935483
# Avg_Word_Length: 6.6415094339622645
# Personal_Pronoun_Count: 1
#
# Results for blackassign0057.txt:
# Positive_Score: 20
# Negative_Score: 9
# Polarity_Score: 0.37931033174791956
# Subjectivity_Score: 0.06590909075929752
# Avg_Sentence_Length: 6.296296296296297
# Percentage_of_Complex_Words: 14.318181818181818
# Fog_Index: 8.245791245791246
# Avg_Number_of_Words_Per_Sentence: 16.296296296296298
# Complex_Word_Count: 100
# Word_Count: 170
# Avg_Syllables_Per_Word: 1.5886363636363636
# Avg_Word_Length: 7.2
# Personal_Pronoun_Count: 0
#
# Results for blackassign0058.txt:
# Positive_Score: 6
# Negative_Score: 0
# Polarity_Score: 0.9999998333333611
# Subjectivity_Score: 0.03351955288536563
# Avg_Sentence_Length: 9.2
# Percentage_of_Complex_Words: 21.787709497206702
# Fog_Index: 12.39508379888268
# Avg_Number_of_Words_Per_Sentence: 17.9
# Complex_Word_Count: 50
# Word_Count: 92
# Avg_Syllables_Per_Word: 1.770949720670391
# Avg_Word_Length: 7.25
# Personal_Pronoun_Count: 1
#
# Results for blackassign0059.txt:
# Positive_Score: 27
# Negative_Score: 37
# Polarity_Score: -0.15624999755859378
# Subjectivity_Score: 0.06743940983409967
# Avg_Sentence_Length: 7.1454545454545455
# Percentage_of_Complex_Words: 12.644889357218126
# Fog_Index: 7.9161375610690685
# Avg_Number_of_Words_Per_Sentence: 17.254545454545454
# Complex_Word_Count: 156
# Word_Count: 393
# Avg_Syllables_Per_Word: 1.4657534246575343
# Avg_Word_Length: 5.9440203562340965
# Personal_Pronoun_Count: 19
#
# Results for blackassign0060.txt:
# Positive_Score: 11
# Negative_Score: 2
# Polarity_Score: 0.6923076390532585
# Subjectivity_Score: 0.06341463383700179
# Avg_Sentence_Length: 10.11111111111111
# Percentage_of_Complex_Words: 12.195121951219512
# Fog_Index: 8.92249322493225
# Avg_Number_of_Words_Per_Sentence: 22.77777777777778
# Complex_Word_Count: 42
# Word_Count: 91
# Avg_Syllables_Per_Word: 1.5170731707317073
# Avg_Word_Length: 6.175824175824176
# Personal_Pronoun_Count: 1
#
# Results for blackassign0061.txt:
# Positive_Score: 53
# Negative_Score: 19
# Polarity_Score: 0.47222221566358036
# Subjectivity_Score: 0.05669291334118668
# Avg_Sentence_Length: 12.056603773584905
# Percentage_of_Complex_Words: 22.20472440944882
# Fog_Index: 13.70453127321349
# Avg_Number_of_Words_Per_Sentence: 23.962264150943398
# Complex_Word_Count: 382
# Word_Count: 639
# Avg_Syllables_Per_Word: 1.7685039370078741
# Avg_Word_Length: 7.253521126760563
# Personal_Pronoun_Count: 0
#
# Results for blackassign0062.txt:
# Positive_Score: 13
# Negative_Score: 18
# Polarity_Score: -0.1612903173777317
# Subjectivity_Score: 0.05175292144949429
# Avg_Sentence_Length: 8.733333333333333
# Percentage_of_Complex_Words: 13.35559265442404
# Fog_Index: 8.835570395102948
# Avg_Number_of_Words_Per_Sentence: 19.966666666666665
# Complex_Word_Count: 130
# Word_Count: 262
# Avg_Syllables_Per_Word: 1.5175292153589315
# Avg_Word_Length: 6.526717557251908
# Personal_Pronoun_Count: 11
#
# Results for blackassign0063.txt:
# Positive_Score: 24
# Negative_Score: 37
# Polarity_Score: -0.21311475060467622
# Subjectivity_Score: 0.05258620685121878
# Avg_Sentence_Length: 9.884615384615385
# Percentage_of_Complex_Words: 13.879310344827585
# Fog_Index: 9.505570291777188
# Avg_Number_of_Words_Per_Sentence: 22.307692307692307
# Complex_Word_Count: 239
# Word_Count: 514
# Avg_Syllables_Per_Word: 1.5594827586206896
# Avg_Word_Length: 6.319066147859922
# Personal_Pronoun_Count: 7
#
# Results for blackassign0064.txt:
# Positive_Score: 33
# Negative_Score: 48
# Polarity_Score: -0.18518518289894836
# Subjectivity_Score: 0.04124236250445908
# Avg_Sentence_Length: 12.162162162162161
# Percentage_of_Complex_Words: 20.519348268839106
# Fog_Index: 13.07260417240051
# Avg_Number_of_Words_Per_Sentence: 26.54054054054054
# Complex_Word_Count: 506
# Word_Count: 900
# Avg_Syllables_Per_Word: 1.6720977596741344
# Avg_Word_Length: 7.167777777777777
# Personal_Pronoun_Count: 16
#
# Results for blackassign0065.txt:
# Positive_Score: 58
# Negative_Score: 23
# Polarity_Score: 0.43209876009754616
# Subjectivity_Score: 0.04260915305491365
# Avg_Sentence_Length: 11.27536231884058
# Percentage_of_Complex_Words: 12.926957435627957
# Fog_Index: 9.680927901787415
# Avg_Number_of_Words_Per_Sentence: 27.579710144927535
# Complex_Word_Count: 348
# Word_Count: 778
# Avg_Syllables_Per_Word: 1.490803993694167
# Avg_Word_Length: 6.434447300771208
# Personal_Pronoun_Count: 20
#
# Results for blackassign0066.txt:
# Positive_Score: 48
# Negative_Score: 26
# Polarity_Score: 0.29729729327976634
# Subjectivity_Score: 0.04439112174901552
# Avg_Sentence_Length: 9.320987654320987
# Percentage_of_Complex_Words: 13.729016786570744
# Fog_Index: 9.220001776356694
# Avg_Number_of_Words_Per_Sentence: 20.59259259259259
# Complex_Word_Count: 329
# Word_Count: 755
# Avg_Syllables_Per_Word: 1.5017985611510791
# Avg_Word_Length: 6.176158940397351
# Personal_Pronoun_Count: 18
#
# Results for blackassign0067.txt:
# Positive_Score: 26
# Negative_Score: 7
# Polarity_Score: 0.5757575583103771
# Subjectivity_Score: 0.03391572452834972
# Avg_Sentence_Length: 5.806451612903226
# Percentage_of_Complex_Words: 12.833675564681723
# Fog_Index: 7.45605087103398
# Avg_Number_of_Words_Per_Sentence: 15.709677419354838
# Complex_Word_Count: 186
# Word_Count: 360
# Avg_Syllables_Per_Word: 1.4815195071868583
# Avg_Word_Length: 6.336111111111111
# Personal_Pronoun_Count: 1
#
# Results for blackassign0068.txt:
# Positive_Score: 53
# Negative_Score: 8
# Polarity_Score: 0.7377049059392639
# Subjectivity_Score: 0.03767757872904411
# Avg_Sentence_Length: 8.791044776119403
# Percentage_of_Complex_Words: 11.426806670784435
# Fog_Index: 8.087140578761534
# Avg_Number_of_Words_Per_Sentence: 24.16417910447761
# Complex_Word_Count: 279
# Word_Count: 589
# Avg_Syllables_Per_Word: 1.4218653489808524
# Avg_Word_Length: 6.234295415959253
# Personal_Pronoun_Count: 4
#
# Results for blackassign0069.txt:
# Positive_Score: 38
# Negative_Score: 6
# Polarity_Score: 0.7272727107438021
# Subjectivity_Score: 0.08317580324541436
# Avg_Sentence_Length: 13.1875
# Percentage_of_Complex_Words: 15.122873345935728
# Fog_Index: 11.324149338374292
# Avg_Number_of_Words_Per_Sentence: 33.0625
# Complex_Word_Count: 92
# Word_Count: 211
# Avg_Syllables_Per_Word: 1.4820415879017013
# Avg_Word_Length: 6.052132701421801
# Personal_Pronoun_Count: 8
#
# Results for blackassign0070.txt:
# Positive_Score: 50
# Negative_Score: 16
# Polarity_Score: 0.5151515073461893
# Subjectivity_Score: 0.03712035993412803
# Avg_Sentence_Length: 12.588235294117647
# Percentage_of_Complex_Words: 17.604049493813275
# Fog_Index: 12.07691391517237
# Avg_Number_of_Words_Per_Sentence: 26.147058823529413
# Complex_Word_Count: 445
# Word_Count: 856
# Avg_Syllables_Per_Word: 1.6355455568053994
# Avg_Word_Length: 6.720794392523365
# Personal_Pronoun_Count: 7
#
# Results for blackassign0071.txt:
# Positive_Score: 33
# Negative_Score: 72
# Polarity_Score: -0.3714285678911565
# Subjectivity_Score: 0.09234828487920115
# Avg_Sentence_Length: 6.027777777777778
# Percentage_of_Complex_Words: 12.401055408970976
# Fog_Index: 7.371533274699502
# Avg_Number_of_Words_Per_Sentence: 15.791666666666666
# Complex_Word_Count: 203
# Word_Count: 434
# Avg_Syllables_Per_Word: 1.4670184696569921
# Avg_Word_Length: 6.276497695852535
# Personal_Pronoun_Count: 13
#
# Results for blackassign0072.txt:
# Positive_Score: 76
# Negative_Score: 23
# Polarity_Score: 0.535353529945924
# Subjectivity_Score: 0.07355126294684156
# Avg_Sentence_Length: 6.8125
# Percentage_of_Complex_Words: 11.069836552748885
# Fog_Index: 7.152934621099554
# Avg_Number_of_Words_Per_Sentence: 16.825
# Complex_Word_Count: 207
# Word_Count: 545
# Avg_Syllables_Per_Word: 1.424219910846954
# Avg_Word_Length: 5.985321100917432
# Personal_Pronoun_Count: 5
#
# Results for blackassign0073.txt:
# Positive_Score: 28
# Negative_Score: 44
# Polarity_Score: -0.2222222191358025
# Subjectivity_Score: 0.05529953912803414
# Avg_Sentence_Length: 12.538461538461538
# Percentage_of_Complex_Words: 11.28165771297007
# Fog_Index: 9.528047700572642
# Avg_Number_of_Words_Per_Sentence: 25.057692307692307
# Complex_Word_Count: 247
# Word_Count: 652
# Avg_Syllables_Per_Word: 1.4773599386032232
# Avg_Word_Length: 5.964723926380368
# Personal_Pronoun_Count: 6
#
# Results for blackassign0074.txt:
# Positive_Score: 36
# Negative_Score: 26
# Polarity_Score: 0.16129031997918838
# Subjectivity_Score: 0.037735849033636124
# Avg_Sentence_Length: 9.555555555555555
# Percentage_of_Complex_Words: 17.163724893487522
# Fog_Index: 10.68771217961723
# Avg_Number_of_Words_Per_Sentence: 20.28395061728395
# Complex_Word_Count: 367
# Word_Count: 774
# Avg_Syllables_Per_Word: 1.6378575776019477
# Avg_Word_Length: 6.602067183462532
# Personal_Pronoun_Count: 10
#
# Results for blackassign0075.txt:
# Positive_Score: 34
# Negative_Score: 80
# Polarity_Score: -0.403508768390274
# Subjectivity_Score: 0.09515859758334005
# Avg_Sentence_Length: 6.1866666666666665
# Percentage_of_Complex_Words: 12.85475792988314
# Fog_Index: 7.616569838619923
# Avg_Number_of_Words_Per_Sentence: 15.973333333333333
# Complex_Word_Count: 223
# Word_Count: 464
# Avg_Syllables_Per_Word: 1.481636060100167
# Avg_Word_Length: 6.349137931034483
# Personal_Pronoun_Count: 15
#
# Results for blackassign0076.txt:
# Positive_Score: 55
# Negative_Score: 33
# Polarity_Score: 0.24999999715909094
# Subjectivity_Score: 0.05045871556739752
# Avg_Sentence_Length: 12.225806451612904
# Percentage_of_Complex_Words: 14.105504587155963
# Fog_Index: 10.532524415507547
# Avg_Number_of_Words_Per_Sentence: 28.129032258064516
# Complex_Word_Count: 327
# Word_Count: 758
# Avg_Syllables_Per_Word: 1.5189220183486238
# Avg_Word_Length: 6.201846965699208
# Personal_Pronoun_Count: 5
#
# Results for blackassign0077.txt:
# Positive_Score: 25
# Negative_Score: 13
# Polarity_Score: 0.31578946537396146
# Subjectivity_Score: 0.044392523312625554
# Avg_Sentence_Length: 15.423076923076923
# Percentage_of_Complex_Words: 15.186915887850466
# Fog_Index: 12.243997124370956
# Avg_Number_of_Words_Per_Sentence: 32.92307692307692
# Complex_Word_Count: 217
# Word_Count: 401
# Avg_Syllables_Per_Word: 1.6144859813084111
# Avg_Word_Length: 6.870324189526184
# Personal_Pronoun_Count: 1
#
# Results for blackassign0078.txt:
# Positive_Score: 40
# Negative_Score: 25
# Polarity_Score: 0.23076922721893497
# Subjectivity_Score: 0.04861630512444554
# Avg_Sentence_Length: 16.675
# Percentage_of_Complex_Words: 18.460388639760836
# Fog_Index: 14.054155455904334
# Avg_Number_of_Words_Per_Sentence: 33.45
# Complex_Word_Count: 364
# Word_Count: 667
# Avg_Syllables_Per_Word: 1.6846038863976083
# Avg_Word_Length: 6.908545727136432
# Personal_Pronoun_Count: 1
#
# Results for blackassign0079.txt:
# Positive_Score: 42
# Negative_Score: 50
# Polarity_Score: -0.08695652079395086
# Subjectivity_Score: 0.048703017443778175
# Avg_Sentence_Length: 10.871794871794872
# Percentage_of_Complex_Words: 16.03174603174603
# Fog_Index: 10.761416361416362
# Avg_Number_of_Words_Per_Sentence: 24.23076923076923
# Complex_Word_Count: 443
# Word_Count: 848
# Avg_Syllables_Per_Word: 1.5571428571428572
# Avg_Word_Length: 6.5495283018867925
# Personal_Pronoun_Count: 6
#
# Results for blackassign0080.txt:
# Positive_Score: 35
# Negative_Score: 11
# Polarity_Score: 0.5217391190926278
# Subjectivity_Score: 0.012051349223984452
# Avg_Sentence_Length: 10.925133689839573
# Percentage_of_Complex_Words: 13.310669456066945
# Fog_Index: 9.694321258362606
# Avg_Number_of_Words_Per_Sentence: 20.449197860962567
# Complex_Word_Count: 758
# Word_Count: 2043
# Avg_Syllables_Per_Word: 1.4966004184100419
# Avg_Word_Length: 5.969652471855115
# Personal_Pronoun_Count: 2
#
# Results for blackassign0081.txt:
# Positive_Score: 40
# Negative_Score: 52
# Polarity_Score: -0.1304347811909263
# Subjectivity_Score: 0.048066875627969234
# Avg_Sentence_Length: 10.325301204819278
# Percentage_of_Complex_Words: 15.979112271540469
# Fog_Index: 10.5217653905439
# Avg_Number_of_Words_Per_Sentence: 23.072289156626507
# Complex_Word_Count: 444
# Word_Count: 857
# Avg_Syllables_Per_Word: 1.5780678851174934
# Avg_Word_Length: 6.639439906651108
# Personal_Pronoun_Count: 12
#
# Results for blackassign0082.txt:
# Positive_Score: 30
# Negative_Score: 61
# Polarity_Score: -0.34065933691583145
# Subjectivity_Score: 0.05511811020283579
# Avg_Sentence_Length: 14.482758620689655
# Percentage_of_Complex_Words: 21.307506053268767
# Fog_Index: 14.316105869583367
# Avg_Number_of_Words_Per_Sentence: 28.482758620689655
# Complex_Word_Count: 447
# Word_Count: 840
# Avg_Syllables_Per_Word: 1.7427360774818401
# Avg_Word_Length: 6.961904761904762
# Personal_Pronoun_Count: 1
#
# Results for blackassign0083.txt:
# Positive_Score: 5
# Negative_Score: 3
# Polarity_Score: 0.24999996875000394
# Subjectivity_Score: 0.043010752456931436
# Avg_Sentence_Length: 9.625
# Percentage_of_Complex_Words: 13.440860215053762
# Fog_Index: 9.226344086021504
# Avg_Number_of_Words_Per_Sentence: 23.25
# Complex_Word_Count: 28
# Word_Count: 77
# Avg_Syllables_Per_Word: 1.4946236559139785
# Avg_Word_Length: 6.259740259740259
# Personal_Pronoun_Count: 2
#
# Results for blackassign0084.txt:
# Positive_Score: 46
# Negative_Score: 4
# Polarity_Score: 0.8399999832000004
# Subjectivity_Score: 0.04456327981767978
# Avg_Sentence_Length: 10.361702127659575
# Percentage_of_Complex_Words: 12.344582593250445
# Fog_Index: 9.082513888364009
# Avg_Number_of_Words_Per_Sentence: 23.95744680851064
# Complex_Word_Count: 210
# Word_Count: 487
# Avg_Syllables_Per_Word: 1.4618117229129663
# Avg_Word_Length: 6.006160164271047
# Personal_Pronoun_Count: 2
#
# Results for blackassign0085.txt:
# Positive_Score: 49
# Negative_Score: 34
# Polarity_Score: 0.18072288938888087
# Subjectivity_Score: 0.041048466844189675
# Avg_Sentence_Length: 6.1
# Percentage_of_Complex_Words: 15.82591493570722
# Fog_Index: 8.770365974282887
# Avg_Number_of_Words_Per_Sentence: 16.85
# Complex_Word_Count: 414
# Word_Count: 732
# Avg_Syllables_Per_Word: 1.5316518298714143
# Avg_Word_Length: 7.120218579234972
# Personal_Pronoun_Count: 6
#
# Results for blackassign0086.txt:
# Positive_Score: 57
# Negative_Score: 15
# Polarity_Score: 0.5833333252314816
# Subjectivity_Score: 0.03694202153055822
# Avg_Sentence_Length: 9.446808510638299
# Percentage_of_Complex_Words: 14.710404920553563
# Fog_Index: 9.662885372476746
# Avg_Number_of_Words_Per_Sentence: 20.75531914893617
# Complex_Word_Count: 417
# Word_Count: 888
# Avg_Syllables_Per_Word: 1.5376729882111737
# Avg_Word_Length: 6.298423423423423
# Personal_Pronoun_Count: 5
#
# Results for blackassign0087.txt:
# Positive_Score: 38
# Negative_Score: 34
# Polarity_Score: 0.05555555478395063
# Subjectivity_Score: 0.060606060555045395
# Avg_Sentence_Length: 11.891304347826088
# Percentage_of_Complex_Words: 14.562289562289562
# Fog_Index: 10.581437564046261
# Avg_Number_of_Words_Per_Sentence: 25.82608695652174
# Complex_Word_Count: 253
# Word_Count: 547
# Avg_Syllables_Per_Word: 1.5648148148148149
# Avg_Word_Length: 6.542961608775137
# Personal_Pronoun_Count: 3
#
# Results for blackassign0088.txt:
# Positive_Score: 17
# Negative_Score: 43
# Polarity_Score: -0.43333332611111125
# Subjectivity_Score: 0.03236245952947008
# Avg_Sentence_Length: 15.311475409836065
# Percentage_of_Complex_Words: 19.623655913978492
# Fog_Index: 13.974052529525824
# Avg_Number_of_Words_Per_Sentence: 30.491803278688526
# Complex_Word_Count: 491
# Word_Count: 934
# Avg_Syllables_Per_Word: 1.6833333333333333
# Avg_Word_Length: 6.790149892933619
# Personal_Pronoun_Count: 1
#
# Results for blackassign0089.txt:
# Positive_Score: 19
# Negative_Score: 42
# Polarity_Score: -0.3770491741467349
# Subjectivity_Score: 0.05663881146087389
# Avg_Sentence_Length: 10.270833333333334
# Percentage_of_Complex_Words: 15.491651205936922
# Fog_Index: 10.304993815708102
# Avg_Number_of_Words_Per_Sentence: 22.458333333333332
# Complex_Word_Count: 264
# Word_Count: 493
# Avg_Syllables_Per_Word: 1.5918367346938775
# Avg_Word_Length: 6.795131845841785
# Personal_Pronoun_Count: 5
#
# Results for blackassign0090.txt:
# Positive_Score: 43
# Negative_Score: 48
# Polarity_Score: -0.05494505434126314
# Subjectivity_Score: 0.06750741834754642
# Avg_Sentence_Length: 7.575342465753424
# Percentage_of_Complex_Words: 14.910979228486648
# Fog_Index: 8.99452867769603
# Avg_Number_of_Words_Per_Sentence: 18.465753424657535
# Complex_Word_Count: 253
# Word_Count: 553
# Avg_Syllables_Per_Word: 1.5274480712166172
# Avg_Word_Length: 6.585895117540687
# Personal_Pronoun_Count: 37
#
# Results for blackassign0091.txt:
# Positive_Score: 31
# Negative_Score: 28
# Polarity_Score: 0.050847456765297346
# Subjectivity_Score: 0.050298380178773756
# Avg_Sentence_Length: 14.18918918918919
# Percentage_of_Complex_Words: 17.88756388415673
# Fog_Index: 12.830701229338368
# Avg_Number_of_Words_Per_Sentence: 31.72972972972973
# Complex_Word_Count: 274
# Word_Count: 525
# Avg_Syllables_Per_Word: 1.6243611584327087
# Avg_Word_Length: 6.699047619047619
# Personal_Pronoun_Count: 12
#
# Results for blackassign0092.txt:
# Positive_Score: 25
# Negative_Score: 40
# Polarity_Score: -0.23076922721893497
# Subjectivity_Score: 0.05216693414753857
# Avg_Sentence_Length: 13.10204081632653
# Percentage_of_Complex_Words: 16.42628205128205
# Fog_Index: 11.811329147043432
# Avg_Number_of_Words_Per_Sentence: 25.46938775510204
# Complex_Word_Count: 297
# Word_Count: 642
# Avg_Syllables_Per_Word: 1.6081730769230769
# Avg_Word_Length: 6.431464174454828
# Personal_Pronoun_Count: 4
#
# Results for blackassign0093.txt:
# Positive_Score: 6
# Negative_Score: 3
# Polarity_Score: 0.33333329629630043
# Subjectivity_Score: 0.042857142653061224
# Avg_Sentence_Length: 8.6
# Percentage_of_Complex_Words: 10.90047393364929
# Fog_Index: 7.800189573459716
# Avg_Number_of_Words_Per_Sentence: 21.1
# Complex_Word_Count: 31
# Word_Count: 86
# Avg_Syllables_Per_Word: 1.4170616113744077
# Avg_Word_Length: 5.953488372093023
# Personal_Pronoun_Count: 2
#
# Results for blackassign0094.txt:
# Positive_Score: 34
# Negative_Score: 49
# Polarity_Score: -0.18072288938888087
# Subjectivity_Score: 0.06484374994934082
# Avg_Sentence_Length: 9.580645161290322
# Percentage_of_Complex_Words: 14.285714285714285
# Fog_Index: 9.546543778801842
# Avg_Number_of_Words_Per_Sentence: 20.661290322580644
# Complex_Word_Count: 260
# Word_Count: 594
# Avg_Syllables_Per_Word: 1.5245901639344261
# Avg_Word_Length: 6.2407407407407405
# Personal_Pronoun_Count: 13
#
# Results for blackassign0095.txt:
# Positive_Score: 12
# Negative_Score: 25
# Polarity_Score: -0.35135134185536915
# Subjectivity_Score: 0.05255681810716361
# Avg_Sentence_Length: 10.870967741935484
# Percentage_of_Complex_Words: 14.914772727272727
# Fog_Index: 10.314296187683285
# Avg_Number_of_Words_Per_Sentence: 22.70967741935484
# Complex_Word_Count: 156
# Word_Count: 337
# Avg_Syllables_Per_Word: 1.5511363636363635
# Avg_Word_Length: 6.356083086053412
# Personal_Pronoun_Count: 4
#
# Results for blackassign0096.txt:
# Positive_Score: 31
# Negative_Score: 57
# Polarity_Score: -0.2954545420971075
# Subjectivity_Score: 0.0724876440918553
# Avg_Sentence_Length: 12.06
# Percentage_of_Complex_Words: 20.476973684210524
# Fog_Index: 13.01478947368421
# Avg_Number_of_Words_Per_Sentence: 24.32
# Complex_Word_Count: 340
# Word_Count: 603
# Avg_Syllables_Per_Word: 1.700657894736842
# Avg_Word_Length: 7.023217247097844
# Personal_Pronoun_Count: 4
#
# Results for blackassign0097.txt:
# Positive_Score: 33
# Negative_Score: 35
# Polarity_Score: -0.02941176427335641
# Subjectivity_Score: 0.056338028122338
# Avg_Sentence_Length: 12.078947368421053
# Percentage_of_Complex_Words: 12.261806130903064
# Fog_Index: 9.736301399729648
# Avg_Number_of_Words_Per_Sentence: 31.763157894736842
# Complex_Word_Count: 197
# Word_Count: 459
# Avg_Syllables_Per_Word: 1.455675227837614
# Avg_Word_Length: 6.276688453159041
# Personal_Pronoun_Count: 7
#
# Results for blackassign0098.txt:
# Positive_Score: 8
# Negative_Score: 2
# Polarity_Score: 0.599999940000006
# Subjectivity_Score: 0.024449877690831595
# Avg_Sentence_Length: 11.526315789473685
# Percentage_of_Complex_Words: 19.315403422982886
# Fog_Index: 12.336687684982628
# Avg_Number_of_Words_Per_Sentence: 21.526315789473685
# Complex_Word_Count: 104
# Word_Count: 219
# Avg_Syllables_Per_Word: 1.63080684596577
# Avg_Word_Length: 6.575342465753424
# Personal_Pronoun_Count: 0
#
# Results for blackassign0099.txt:
# Positive_Score: 26
# Negative_Score: 3
# Polarity_Score: 0.7931034209274682
# Subjectivity_Score: 0.04374057308636414
# Avg_Sentence_Length: 9.030303030303031
# Percentage_of_Complex_Words: 9.95475113122172
# Fog_Index: 7.594021664609901
# Avg_Number_of_Words_Per_Sentence: 20.09090909090909
# Complex_Word_Count: 122
# Word_Count: 298
# Avg_Syllables_Per_Word: 1.4464555052790347
# Avg_Word_Length: 6.063758389261745
# Personal_Pronoun_Count: 4
#
# Results for blackassign0100.txt:
# Positive_Score: 38
# Negative_Score: 57
# Polarity_Score: -0.19999999789473688
# Subjectivity_Score: 0.0865209470978862
# Avg_Sentence_Length: 16.28125
# Percentage_of_Complex_Words: 17.727272727272727
# Fog_Index: 13.603409090909091
# Avg_Number_of_Words_Per_Sentence: 34.375
# Complex_Word_Count: 283
# Word_Count: 521
# Avg_Syllables_Per_Word: 1.6227272727272728
# Avg_Word_Length: 6.769673704414587
# Personal_Pronoun_Count: 3

# %% [markdown]
# Pandas DataFrame:<br>
# The existing Excel file is read into a Pandas DataFrame using pd.read_excel(input_file).<br>
#
# DataFrame Update:<br>
# The DataFrame is then updated with the computed values for each URL_ID. The URL_ID is used to locate the corresponding row in the DataFrame.<br>
#
# Data Writing:<br>
# The updated DataFrame is written back to the Excel file using df.to_excel(output_file, index=False).<br>
#
# Exception Handling:<br>
# If the input file is not found, an exception is caught, and a message is printed indicating that the file path should be checked.

# %%
import pandas as pd
def update_excel_file(input_file, output_file, results_dict):
    try:
        df = pd.read_excel(input_file)
        for url_id, results in results_dict.items():
            # checking if the URL_ID exists in the DataFrame
            if url_id in df['URL_ID'].values:
                index = df.index[df['URL_ID'] == url_id].tolist()[0]

                df.at[index, 'POSITIVE SCORE'] = results[0]
                df.at[index, 'NEGATIVE SCORE'] = results[1]
                df.at[index, 'POLARITY SCORE'] = results[2]
                df.at[index, 'SUBJECTIVITY SCORE'] = results[3]
                df.at[index, 'AVG SENTENCE LENGTH'] = results[4]
                df.at[index, 'PERCENTAGE OF COMPLEX WORDS'] = results[5]
                df.at[index, 'FOG INDEX'] = results[6]
                df.at[index, 'AVG NUMBER OF WORDS PER SENTENCE'] = results[7]
                df.at[index, 'COMPLEX WORD COUNT'] = results[8]
                df.at[index, 'WORD COUNT'] = results[9]
                df.at[index, 'SYLLABLE PER WORD'] = results[10]
                df.at[index, 'PERSONAL PRONOUNS'] = results[11]
                df.at[index, 'AVG WORD LENGTH'] = results[12]

        df.to_excel(output_file, index=False) # writing the updated data back to the Excel file
        print("Data updated and written to the Excel file successfully.")

    except FileNotFoundError:
        print(f"Input file {input_file} not found. Please check the file path.")

results_dict = {} # dictionary to store results for each URL_ID

for i in range(1, 101):
    file_name = f"blackassign{str(i).zfill(4)}.txt"
    file_path = f"{file_name}"

    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            article_text = file.read()
        results = analyze_text(article_text, positive_words, negative_words, stop_words)
        url_id = f"blackassign{str(i).zfill(4)}"
        results_dict[url_id] = results
    except FileNotFoundError:
        print(f"\nFile {file_name} not found. Skipping...")
update_excel_file("Output Data Structure.xlsx", "Output Data Structure.xlsx", results_dict)
# Out:
# File blackassign0036.txt not found. Skipping...
#
# File blackassign0049.txt not found. Skipping...
# Data updated and written to the Excel file successfully.
